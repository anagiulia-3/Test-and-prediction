# %% [markdown]
# <a href="https://colab.research.google.com/github/anagiulia-3/Test-and-prediction/blob/main/TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import das bibliotecas

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import sklearn
class def
# Out:
# 1.6.1

# %%
import pandas as pd
database = pd.read_csv('/content/drive/MyDrive/TCC - database final.csv')
database.head()
database = database.dropna()
database['date'] = pd.to_datetime(database['date'])
database = database.sort_values(by='date').reset_index(drop=True)



display(database)
# Out:
#           date product  production [ton]  plantation [hec]  precipitação [mm]  \
# 0   2006-09-01   Trigo         1220000.0          886194.0         227.800000
# 1   2006-10-01   Trigo         1160000.0          886602.0          87.866667
# 2   2006-11-01   Trigo         1135476.0          878722.0         176.100000
# 3   2006-12-01   Trigo         1135476.0          878722.0         143.422222
# 4   2007-01-01   Trigo         1933188.0          878722.0         236.560000
# ..         ...     ...               ...               ...                ...
# 226 2025-07-01   Trigo         2608800.0          832800.0          42.153846
# 227 2025-08-01   Trigo         2624600.0          820400.0          61.753846
# 228 2025-09-01   Trigo         2678900.0          824900.0          77.742857
# 229 2025-10-01   Trigo         2751900.0          818900.0         176.166667
# 230 2025-11-01   Trigo         2774000.0          816600.0         154.666667
#
# ...
